# %%
import torch
from torch.autograd import Variable
import torch.nn.functional as F
import torch.utils.data as Data

import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd
import imageio

# %%
torch.manual_seed(1)

# %%
dataset = pd.read_csv('SeoulBikeData.csv', encoding= 'unicode_escape')

# %%
#x = torch.unsqueeze(torch.linspace(-1, 1, 100), dim=1)  # x data (tensor), shape=(100, 1)
#y = x.pow(2) + 0.2*torch.rand(x.size())                 # noisy y data (tensor), shape=(100, 1)

x = dataset[dataset.columns[2:-1]]
x["Date"] = dataset.loc[:, 'Date']

y = dataset[dataset.columns[1]]

print(x)
print()
print(y)
# Out:
# C:\Users\imbrm\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#       Hour  Temperature(°C)  Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# 0        0             -5.2           37               2.2              2000
# 1        1             -5.5           38               0.8              2000
# 2        2             -6.0           39               1.0              2000
# 3        3             -6.2           40               0.9              2000
# 4        4             -6.0           36               2.3              2000
# ...    ...              ...          ...               ...               ...
# 8755    19              4.2           34               2.6              1894
# 8756    20              3.4           37               2.3              2000
# 8757    21              2.6           39               0.3              1968
# 8758    22              2.1           41               1.0              1859
# 8759    23              1.9           43               1.3              1909
#
#       Dew point temperature(°C)  Solar Radiation (MJ/m2)  Rainfall(mm)  \
# 0                         -17.6                      0.0           0.0
# 1                         -17.6                      0.0           0.0
# 2                         -17.7                      0.0           0.0
# 3                         -17.6                      0.0           0.0
# 4                         -18.6                      0.0           0.0
# ...                         ...                      ...           ...
# 8755                      -10.3                      0.0           0.0
# 8756                       -9.9                      0.0           0.0
# 8757                       -9.9                      0.0           0.0
# 8758                       -9.8                      0.0           0.0
# 8759                       -9.3                      0.0           0.0
#
#       Snowfall (cm) Seasons     Holiday        Date
# 0               0.0  Winter  No Holiday  01/12/2017
# 1               0.0  Winter  No Holiday  01/12/2017
# 2               0.0  Winter  No Holiday  01/12/2017
# 3               0.0  Winter  No Holiday  01/12/2017
# 4               0.0  Winter  No Holiday  01/12/2017
# ...             ...     ...         ...         ...
# 8755            0.0  Autumn  No Holiday  30/11/2018
# 8756            0.0  Autumn  No Holiday  30/11/2018
# 8757            0.0  Autumn  No Holiday  30/11/2018
# 8758            0.0  Autumn  No Holiday  30/11/2018
# 8759            0.0  Autumn  No Holiday  30/11/2018
#
# [8760 rows x 12 columns]
#
# 0        254
# 1        204
# 2        173
# 3        107
# 4         78
#         ...
# 8755    1003
# 8756     764
# 8757     694
# 8758     712
# 8759     584
# Name: Rented Bike Count, Length: 8760, dtype: int64

# %%
# torch can only train on Variable, so convert them to Variable
x, y = Variable(x), Variable(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-523c0fe9565e> in <module>
#       1 # torch can only train on Variable, so convert them to Variable
# ----> 2 x, y = Variable(x), Variable(y)
#
# TypeError: Variable data has to be a tensor, but got DataFrame

# %%
# view data
plt.figure(figsize=(10,4))
plt.scatter(x.data.numpy(), y.data.numpy(), color = "orange")
plt.title('Regression Analysis')
plt.xlabel('Independent varible')
plt.ylabel('Dependent varible')
plt.show()
